# %% [markdown]
# # Build multiclass classifiers with Amazon SageMaker linear learner

# %% [markdown]
# Amazon SageMaker is a fully managed service for scalable training and hosting of machine learning models. We're adding multiclass classification support to the linear learner algorithm in Amazon SageMaker. Linear learner already provides convenient APIs for linear models such as logistic regression for ad click prediction, fraud detection, or other classification problems, and linear regression for forecasting sales, predicting delivery times, or other problems where you want to predict a numerical value. If you haven't worked with linear learner before, you might want to start with the [documentation](https://docs.aws.amazon.com/sagemaker/latest/dg/linear-learner.html) or our previous [example notebook](https://github.com/awslabs/amazon-sagemaker-examples/blob/master/scientific_details_of_algorithms/linear_learner_class_weights_loss_functions/linear_learner_class_weights_loss_functions.ipynb) on this algorithm. If it's your first time working with Amazon SageMaker, you can get started [here](https://aws.amazon.com/about-aws/whats-new/2017/11/introducing-amazon-sagemaker/).

# %% [markdown]
# In this example notebook we'll cover three aspects of training a multiclass classifier with linear learner:
# 1. Training a multiclass classifier
# 1. Multiclass classification metrics
# 1. Training with balanced class weights

# %% [markdown]
# ## Training a multiclass classifier
# Multiclass classification is a machine learning task where the outputs are known to be in a finite set of labels. For example, we might classify emails by assigning each one a label from the set *inbox, work, shopping, spam*. Or we might try to predict what a customer will buy from the set *shirt, mug, bumper_sticker, no_purchase*. If we have a dataset where each example has numerical features and a known categorical label, we can train a multiclass classifier.

# %% [markdown]
# ### Related problems: binary, multiclass, and multilabel
# Multiclass classification is related to two other machine learning tasks, binary classification and the multilabel problem. Binary classification is already supported by linear learner, and multiclass classification is available with linear learner starting today, but multilabel support is not yet available from linear learner.

# %% [markdown]
# If there are only two possible labels in your dataset, then you have a binary classification problem. Examples include predicting whether a transaction will be fraudulent or not based on transaction and customer data, or detecting whether a person is smiling or not based on features extracted from a photo. For each example in your dataset, one of the possible labels is correct and the other is incorrect. The person is smiling or not smiling.

# %% [markdown]
# If there are more than two possible labels in your dataset, then you have a multiclass classification problem. For example, predicting whether a transaction will be fraudulent, cancelled, returned, or completed as usual. Or detecting whether a person in a photo is smiling, frowning, surprised, or frightened. There are multiple possible labels, but only one is correct at a time.

# %% [markdown]
# If there are multiple labels, and a single training example can have more than one correct label, then you have a multilabel problem. For example, tagging an image with tags from a known set. An image of a dog catching a Frisbee at the park might be labeled as *outdoors*, *dog*, and *park*. For any given image, those three labels could all be true, or all be false, or any combination. Although we haven't added support for multilabel problems yet, there are a couple of ways you can solve a multilabel problem with linear learner today. You can train a separate binary classifier for each label. Or you can train a multiclass classifier and predict not only the top class, but the top k classes, or all classes with probability scores above some threshold.

# %% [markdown]
# Linear learner uses a softmax loss function to train multiclass classifiers. The algorithm learns a set of weights for each class, and predicts a probability for each class. We might want to use these probabilities directly, for example if we're classifying emails as *inbox, work, shopping, spam* and we have a policy to flag as spam only if the class probability is over 99.99%. But in many multiclass classification use cases, we'll simply take the class with highest probability as the predicted label.

# %% [markdown]
# ### Hands-on example: predicting forest cover type
# As an example of multiclass prediction, let's take a look at the [Covertype dataset](https://archive.ics.uci.edu/ml/datasets/covertype) (copyright Jock A. Blackard and Colorado State University). The dataset contains information collected by the US Geological Survey and the US Forest Service about wilderness areas in northern Colorado. The features are measurements like soil type, elevation, and distance to water, and the labels encode the type of trees - the forest cover type - for each location. The machine learning task is to predict the cover type in a given location using the features. We'll download and explore the dataset, then train a multiclass classifier with linear learner using the Python SDK.

# %%
# import data science and visualization libraries
# %matplotlib inline
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
import seaborn as sns

# %%
# download the raw data and unzip
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/covtype/covtype.data.gz
# !gunzip covtype.data.gz
# Out:
# --2019-04-25 15:00:51--  https://archive.ics.uci.edu/ml/machine-learning-databases/covtype/covtype.data.gz
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11240707 (11M) [application/x-httpd-php]
# Saving to: ‘covtype.data.gz’
#
# covtype.data.gz     100%[===================>]  10.72M  11.7MB/s    in 0.9s
#
# 2019-04-25 15:00:52 (11.7 MB/s) - ‘covtype.data.gz’ saved [11240707/11240707]

# %%
# read the csv and extract features and labels
covtype = pd.read_csv('covtype.data', delimiter=',', dtype='float32').values
covtype_features, covtype_labels = covtype[:, :54], covtype[:, 54]
# transform labels to 0 index
covtype_labels -= 1
# shuffle and split into train and test sets
np.random.seed(0)
train_features, test_features, train_labels, test_labels = train_test_split(
    covtype_features, covtype_labels, test_size=0.2)
# further split the test set into validation and test sets
val_features, test_features, val_labels, test_labels = train_test_split(
    test_features, test_labels, test_size=0.5)

# %% [markdown]
# Note that we transformed the labels to a zero index rather than an index starting from one. That step is important, since linear learner requires the class labels to be in the range \[0, k-1\], where k is the number of labels. Amazon SageMaker algorithms expect the `dtype` of all feature and label values to be `float32`. Also note that we shuffled the order of examples in the training set. We used the `train_test_split` method from `numpy`, which shuffles the rows by default. That's important for algorithms trained using stochastic gradient descent. Linear learner, as well as most deep learning algorithms, use stochastic gradient descent for optimization. Shuffle your training examples, unless your data have some natural ordering which needs to be preserved, such as a forecasting problem where the training examples should all have time stamps earlier than the test examples.

# %% [markdown]
# We split the data into training, validation, and test sets with an 80/10/10 ratio. Using a validation set will improve training, since linear learner uses the validation data to stop training once overfitting is detected. That means shorter training times and more accurate predictions. We can also provide a test set to linear learner. The test set will not affect the final model, but algorithm logs will contain metrics from the final model's performance on the test set. Later on in this example notebook, we'll also use the test set locally to dive a little bit deeper on model performance.

# %% [markdown]
# ### Exploring the data
# Let's take a look at the mix of class labels present in training data. We'll add meaningful category names using the mapping provided in the [dataset documentation](https://archive.ics.uci.edu/ml/machine-learning-databases/covtype/covtype.info).

# %%
# assign label names and count label frequencies
label_map = {0:'Spruce/Fir', 1:'Lodgepole Pine', 2:'Ponderosa Pine', 3:'Cottonwood/Willow', 
             4:'Aspen', 5:'Douglas-fir', 6:'Krummholz'}
label_counts = pd.DataFrame(data=train_labels)[0].map(label_map).value_counts(sort=False).sort_index(ascending=False)
label_counts.plot('barh', color='tomato', title='Label Counts')

# %% [markdown]
# We can see that some forest cover types are much more common than others. Lodgepole Pine and Spruce/Fir are both well represented. Some labels, such as Cottonwood/Willow, are extremely rare. Later in this example notebook, we'll see how to fine-tune the algorithm depending on how important these rare categories are for our use case. But first we'll train with the defaults for the best all-around model.

# %% [markdown]
# ### Training a classifier using the Amazon SageMaker Python SDK
# We'll use the high-level estimator class `LinearLearner` to instantiate our training job and inference endpoint. For an example using the Python SDK's generic `Estimator` class, take a look at this previous [example notebook](https://github.com/awslabs/amazon-sagemaker-examples/blob/master/scientific_details_of_algorithms/linear_learner_class_weights_loss_functions/linear_learner_class_weights_loss_functions.ipynb). The generic Python SDK estimator offers some more control options, but the high-level estimator is more succinct and has some advantages. One is that we don't need to specify the location of the algorithm container we want to use for training. It will pick up the latest version of the linear learner algorithm. Another advantage is that some code errors will be surfaced before a training cluster is spun up, rather than after. For example, if we try to pass `n_classes=7` instead of the correct `num_classes=7`, then the high-level estimator will fail immediately, but the generic Python SDK estimator will spin up a cluster before failing.

# %%
import sagemaker
from sagemaker.amazon.amazon_estimator import RecordSet
import boto3

# instantiate the LinearLearner estimator object
multiclass_estimator = sagemaker.LinearLearner(role=sagemaker.get_execution_role(),
                                               train_instance_count=1,
                                               train_instance_type='ml.m4.xlarge',
                                               predictor_type='multiclass_classifier',
                                               num_classes=7)
# Out:
# INFO:sagemaker:Created S3 bucket: sagemaker-us-east-1-023375022819

# %% [markdown]
# Linear learner accepts training data in protobuf or csv content types, and accepts inference requests in protobuf, csv, or json content types. Training data have features and ground-truth labels, while the data in an inference request has only features. In a production pipeline, we recommend converting the data to the Amazon SageMaker protobuf format and storing it in S3. However, to get up and running quickly, we provide a convenience method `record_set` for converting and uploading  when the dataset is small enough to fit in local memory. It accepts `numpy` arrays like the ones we already have, so we'll use it here. The `RecordSet` object will keep track of the temporary S3 location of our data.

# %%
# wrap data in RecordSet objects
train_records = multiclass_estimator.record_set(train_features, train_labels, channel='train')
val_records = multiclass_estimator.record_set(val_features, val_labels, channel='validation')
test_records = multiclass_estimator.record_set(test_features, test_labels, channel='test')

# %%
# start a training job
multiclass_estimator.fit([train_records, val_records, test_records])
# Out:
# INFO:sagemaker:Creating training-job with name: linear-learner-2019-04-25-15-01-16-749
# 2019-04-25 15:01:17 Starting - Starting the training job...
# 2019-04-25 15:01:19 Starting - Launching requested ML instances......
# 2019-04-25 15:02:30 Starting - Preparing the instances for training......
# 2019-04-25 15:03:36 Downloading - Downloading input data...
# 2019-04-25 15:04:13 Training - Training image download completed. Training in progress..
# Docker entrypoint called with argument(s): train
# [04/25/2019 15:04:15 INFO 140169155405632] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/default-input.json: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [04/25/2019 15:04:15 INFO 140169155405632] Reading provided configuration from /opt/ml/input/config/hyperparameters.json: {u'feature_dim': u'54', u'mini_batch_size': u'1000', u'predictor_type': u'multiclass_classifier', u'num_classes': u'7'}
# [04/25/2019 15:04:15 INFO 140169155405632] Final configuration: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'54', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'7', u'predictor_type': u'multiclass_classifier', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [04/25/2019 15:04:15 WARNING 140169155405632] Loggers have already been setup.
# Process 1 is a worker.
# [04/25/2019 15:04:15 INFO 140169155405632] Using default worker.
# [2019-04-25 15:04:15.645] [tensorio] [info] batch={"data_pipeline": "/opt/ml/input/data/train", "num_examples": 1000, "features": [{"name": "label_values", "shape": [1], "storage_type": "dense"}, {"name": "values", "shape": [54], "storage_type": "dense"}]}
# [2019-04-25 15:04:15.650] [tensorio] [warning] TensorIO is already initialized; ignoring the initialization routine.
# [2019-04-25 15:04:15.651] [tensorio] [info] batch={"data_pipeline": "/opt/ml/input/data/validation", "num_examples": 1000, "features": [{"name": "label_values", "shape": [1], "storage_type": "dense"}, {"name": "values", "shape": [54], "storage_type": "dense"}]}
# [2019-04-25 15:04:15.658] [tensorio] [warning] TensorIO is already initialized; ignoring the initialization routine.
# [2019-04-25 15:04:15.665] [tensorio] [info] batch={"data_pipeline": "/opt/ml/input/data/test", "num_examples": 1000, "features": [{"name": "label_values", "shape": [1], "storage_type": "dense"}, {"name": "values", "shape": [54], "storage_type": "dense"}]}
# [2019-04-25 15:04:15.697] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 0, "duration": 52, "num_examples": 1}
# [04/25/2019 15:04:15 INFO 140169155405632] Create Store: local
# [2019-04-25 15:04:15.865] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch":
#progress_metric: host=algo-1, completed 6 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 465, "sum": 465.0, "min": 465}, "Number of Batches Since Last Reset": {"count": 1, "max": 465, "sum": 465.0, "min": 465}, "Number of Records Since Last Reset": {"count": 1, "max": 464808, "sum": 464808.0, "min": 464808}, "Total Batches Seen": {"count": 1, "max": 477, "sum": 477.0, "min": 477}, "Total Records Seen": {"count": 1, "max": 476808, "sum": 476808.0, "min": 476808}, "Max Records Seen Between Resets": {"count": 1, "max": 464808, "sum": 464808.0, "min": 464808}, "Reset Count": {"count": 1, "max": 3, "sum": 3.0, "min": 3}}, "EndTime": 1556204679.660947, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1556204656.060413}
#
# [04/25/2019 15:04:39 INFO 140169155405632] #throughput_metric: host=algo-1, train throughput=19694.6934337 records/second
# [2019-04-25 15:04:39.661] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 2, "duration": 23600, "num_examples": 465}
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.7026583904397898, "sum": 0.7026583904397898, "min": 0.7026583904397898}}, "EndTime": 1556204702.175313, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1556204702.17525}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.9177241080711628, "sum": 0.9177241080711628, "min": 0.9177241080711628}}, "EndTime": 1556204702.175405, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1556204702.175386}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.6660722614156789, "sum": 0.6660722614156789, "min": 0.6660722614156789}}, "EndTime": 1556204702.175465, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1556204702.175449}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.6726571298796555, "sum": 0.6726571298796555, "min": 0.6726571298796555}}, "EndTime": 1556204702.17552, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1556204702.175505}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.6725293202893488, "sum": 0.6725293202893488, "min": 0.6725293202893488}}, "EndTime": 1556204702.175572, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1556204702.175558}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.7414239059974407, "sum": 0.7414239059974407, "min": 0.7414239059974407}}, "EndTime": 1556204702.175621, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1556204702.175608}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.6849733157980031, "sum": 0.6849733157980031, "min": 0.6849733157980031}}, "EndTime": 1556204702.175676, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1556204702.17566}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.7051124368864915, "sum": 0.7051124368864915, "min": 0.7051124368864915}}, "EndTime": 1556204702.175733, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1556204702.175718}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.6786344375610351, "sum": 0.6786344375610351, "min": 0.6786344375610351}}, "EndTime": 1556204702.175793, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1556204702.175778}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.7088193936841242, "sum": 0.7088193936841242, "min": 0.7088193936841242}}, "EndTime": 1556204702.175858, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1556204702.175841}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.6710566261554587, "sum": 0.6710566261554587, "min": 0.6710566261554587}}, "EndTime": 1556204702.175922, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1556204702.175907}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.758604829590896, "sum": 0.758604829590896, "min": 0.758604829590896}}, "EndTime": 1556204702.175979, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1556204702.175964}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.6681618265612372, "sum": 0.6681618265612372, "min": 0.6681618265612372}}, "EndTime": 1556204702.176041, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1556204702.176025}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.6666416183997845, "sum": 0.6666416183997845, "min": 0.6666416183997845}}, "EndTime": 1556204702.176102, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1556204702.176086}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.8296693450664652, "sum": 0.8296693450664652, "min": 0.8296693450664652}}, "EndTime": 1556204702.176177, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1556204702.176161}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.9918677622038743, "sum": 0.9918677622038743, "min": 0.9918677622038743}}, "EndTime": 1556204702.176237, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1556204702.17622}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.6644684650815766, "sum": 0.6644684650815766, "min": 0.6644684650815766}}, "EndTime": 1556204702.176294, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1556204702.176278}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.8135808852623249, "sum": 0.8135808852623249, "min": 0.8135808852623249}}, "EndTime": 1556204702.176351, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1556204702.176336}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.7124576372607001, "sum": 0.7124576372607001, "min": 0.7124576372607001}}, "EndTime": 1556204702.176408, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1556204702.176392}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.9201165428161621, "sum": 0.9201165428161621, "min": 0.9201165428161621}}, "EndTime": 1556204702.176468, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1556204702.176452}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.7049339936355065, "sum": 0.7049339936355065, "min": 0.7049339936355065}}, "EndTime": 1556204702.176528, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1556204702.176512}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 1

#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.9136916199796727, "sum": 0.9136916199796727, "min": 0.9136916199796727}}, "EndTime": 1556204703.590819, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1556204703.590802}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.6982403707899031, "sum": 0.6982403707899031, "min": 0.6982403707899031}}, "EndTime": 1556204703.590867, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1556204703.590853}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 1.0583548488798482, "sum": 1.0583548488798482, "min": 1.0583548488798482}}, "EndTime": 1556204703.590929, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1556204703.590914}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.7262956957359864, "sum": 0.7262956957359864, "min": 0.7262956957359864}}, "EndTime": 1556204703.590988, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1556204703.590973}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.7753432468814745, "sum": 0.7753432468814745, "min": 0.7753432468814745}}, "EndTime": 1556204703.591049, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1556204703.591034}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.6616143517661544, "sum": 0.6616143517661544, "min": 0.6616143517661544}}, "EndTime": 1556204703.591104, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1556204703.591089}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.7016173105178644, "sum": 0.7016173105178644, "min": 0.7016173105178644}}, "EndTime": 1556204703.59116, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1556204703.591144}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.66617247989421, "sum": 0.66617247989421, "min": 0.66617247989421}}, "EndTime": 1556204703.591216, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1556204703.5912}
#
# [04/25/2019 15:05:03 INFO 140169155405632] #quality_metric: host=algo-1, epoch=1, validation multiclass_cross_entropy_objective <loss>=0.701555015548
# [04/25/2019 15:05:03 INFO 140169155405632] #early_stopping_criteria_metric: host=algo-1, epoch=1, criteria=multiclass_cross_entropy_objective, value=0.66019415562
# [04/25/2019 15:05:03 INFO 140169155405632] Epoch 1: Loss improved. Updating best model
# [04/25/2019 15:05:03 INFO 140169155405632] #progress_metric: host=algo-1, completed 13 % of epochs
# ...
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.6694155046487272, "sum": 0.6694155046487272, "min": 0.6694155046487272}}, "EndTime": 1556204867.138549, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 8}, "StartTime": 1556204867.138533}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.7011635044770418, "sum": 0.7011635044770418, "min": 0.7011635044770418}}, "EndTime": 1556204867.13861, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 8}, "StartTime": 1556204867.138594}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.6644186357141098, "sum": 0.6644186357141098, "min": 0.6644186357141098}}, "EndTime": 1556204867.138667, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 8}, "StartTime": 1556204867.138651}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.6665916278073756, "sum": 0.6665916278073756, "min": 0.6665916278073756}}, "EndTime": 1556204867.138726, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 8}, "StartTime": 1556204867.138713}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.6533206568016895, "sum": 0.6533206568016895, "min": 0.6533206568016895}}, "EndTime": 1556204867.138786, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 8}, "StartTime": 1556204867.13877}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.7429860832133073, "sum": 0.7429860832133073, "min": 0.7429860832133073}}, "EndTime": 1556204867.138838, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 8}, "StartTime": 1556204867.138823}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.6678797769020438, "sum": 0.6678797769020438, "min": 0.6678797769020438}}, "EndTime": 1556204867.138891, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 8}, "StartTime": 1556204867.138876}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.6620761275638191, "sum": 0.6620761275638191, "min": 0.6620761275638191}}, "EndTime": 1556204867.138947, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 8}, "StartTime": 1556204867.138931}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.7450727770466852, "sum": 0.7450727770466852, "min": 0.7450727770466852}}, "EndTime": 1556204867.139011, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 8}, "StartTime": 1556204867.138995}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.8758254337552078, "sum": 0.8758254337552078, "min": 0.8758254337552078}}, "EndTime": 1556204867.139069, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 8}, "StartTime": 1556204867.139053}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.6519111429372283, "sum": 0.6519111429372283, "min": 0.6519111429372283}}, "EndTime": 1556204867.139126, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 8}, "StartTime": 1556204867.13911}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.8131340634701586, "sum": 0.8131340634701586, "min": 0.8131340634701586}}, "EndTime": 1556204867.139185, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 8}, "StartTime": 1556204867.13917}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.6514918958830347, "sum": 0.6514918958830347, "min": 0.6514918958830347}}, "EndTime": 1556204867.139242, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 8}, "StartTime": 1556204867.139227}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.8968254463990374, "sum": 0.8968254463990374, "min": 0.8968254463990374}}, "EndTime": 1556204867.139298, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 8}, "StartTime": 1556204867.139283}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.6944614143244865, "sum": 0.6944614143244865, "min": 0.6944614143244865}}, "EndTime": 1556204867.139363, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 8}, "StartTime": 1556204867.139346}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 1.0416406659800423, "sum": 1.0416406659800423, "min": 1.0416406659800423}}, "EndTime": 1556204867.139429, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 8}, "StartTime": 1556204867.139413}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.7234014384818486, "sum": 0.7234014384818486, "min": 0.7234014384818486}}, "EndTime": 1556204867.139497, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 8}, "StartTime": 1556204867.139481}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.7744953945166018, "sum": 0.7744953945166018, "min": 0.7744953945166018}}, "EndTime": 1556204867.139556, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 8}, "StartTime": 1556204867.13954}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.6538802190064231, "sum": 0.6538802190064231, "min": 0.6538802190064231}}, "EndTime": 1556204867.139613, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 8}, "StartTime": 1556204867.139597}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.6705291106453414, "sum": 0.6705291106453414, "min": 0.6705291106453414}}, "EndTime": 1556204867.139676, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 8}, "StartTime": 1556204867.139661}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.6661712590807825, "sum": 0.6661712590807825, "min": 0.6661712590807825}}, "EndTime": 1556204867.139733, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 8}, "StartTime": 1556204867.139718}
#
# [04/25/2019 15:07:47 INFO 140169155405632] #quality_metric: host=algo-1, epoch=8, validation multiclass_cross_entropy_objective <loss>=0.699895280234
# [04/25/2019 15:07:47 INFO 140169155405632] #early_stopping_criteria_metric: host=algo-1, epoch=8, criteria=multiclass_cross_entropy_objective, value=0.651109217161
# [04/25/2019 15:07:47 INFO 140169155405632] Early stop condition met. Stopping training.
# [04/25/2019 15:07:47 INFO 140169155405632] #progress_metric: host=algo-1, completed 100 % epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 465, "sum": 465.0, "min": 465}, "Number of Batches Since Last Reset": {"count": 1, "max": 465, "sum": 465.0, "min": 465}, "Number of Records Since Last Reset": {"count": 1, "max": 464808, "sum": 464808.0, "min": 464808}, "Total Batches Seen": {"count": 1, "max": 4197, "sum": 4197.0, "min": 4197}, "Total Records Seen": {"count": 1, "max": 4195272, "sum": 4195272.0, "min": 4195272}, "Max Records Seen Between Resets": {"count": 1, "max": 464808, "sum": 464808.0, "min": 464808}, "Reset Count": {"count": 1, "max": 11, "sum": 11.0, "min": 11}}, "EndTime": 1556204867.140728, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 8}, "StartTime": 1556204843.851981}
#
# [04/25/2019 15:07:47 INFO 140169155405632] #throughput_metric: host=algo-1, train throughput=19958.3724319 records/second
# [04/25/2019 15:07:47 WARNING 140169155405632] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [04/25/2019 15:07:47 WARNING 140169155405632] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2019-04-25 15:07:47.157] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/validation", "epoch": 9, "duration": 1431, "num_examples": 59}
# [04/25/2019 15:07:48 INFO 140169155405632] #early_stopping_criteria_metric: host=algo-1, epoch=8, criteria=multiclass_cross_entropy_objective, value=0.651109217161
# [2019-04-25 15:07:48.588] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/validation", "epoch": 10, "duration": 1430, "num_examples": 59}
# [04/25/2019 15:07:49 INFO 140169155405632] #validation_score (algo-1) : ('multiclass_cross_entropy_objective', 0.65171726694476539)
# [04/25/2019 15:07:49 INFO 140169155405632] #validation_score (algo-1) : ('multiclass_accuracy', 0.71859348376103682)
# [04/25/2019 15:07:49 INFO 140169155405632] #validation_score (algo-1) : ('multiclass_top_k_accuracy_3', 0.99271957453400117)
# [04/25/2019 15:07:49 INFO 140169155405632] #validation_score (algo-1) : ('dcg', 0.89084578995835884)
# [04/25/2019 15:07:49 INFO 140169155405632] #validation_score (algo-1) : ('macro_recall', 0.4694936)
# [04/25/2019 15:07:49 INFO 140169155405632] #validation_score (algo-1) : ('macro_precision', 0.58335274)
# [04/25/2019 15:07:49 INFO 140169155405632] #validation_score (algo-1) : ('macro_f_1.000', 0.48478779)
# [04/25/2019 15:07:49 INFO 140169155405632] #quality_metric: host=algo-1, validation multiclass_cross_entropy_objective <loss>=0.651717266945
# [04/25/2019 15:07:49 INFO 140169155405632] #quality_metric: host=algo-1, validation multiclass_accuracy <score>=0.718593483761
# [04/25/2019 15:07:49 INFO 140169155405632] #quality_metric: host=algo-1, validation multiclass_top_k_accuracy_3 <score>=0.992719574534
# [04/25/2019 15:07:49 INFO 140169155405632] #quality_metric: host=algo-1, validation dcg <score>=0.890845789958
# [04/25/2019 15:07:49 INFO 140169155405632] #quality_metric: host=algo-1, validation macro_recall <score>=0.469493597746
# [04/25/2019 15:07:49 INFO 140169155405632] #quality_metric: host=algo-1, validation macro_precision <score>=0.583352744579
# [04/25/2019 15:07:49 INFO 140169155405632] #quality_metric: host=algo-1, validation macro_f_1.000 <score>=0.484787791967
# [04/25/2019 15:07:49 INFO 140169155405632] Best model found for hyperparameters: {"lr_scheduler_step": 17, "wd": 0.0018430058738815975, "optimizer": "rmsprop", "lr_scheduler_factor": 0.9744439705222135, "l1": 0.28713437887544363, "learning_rate": 0.04894414201957118, "lr_scheduler_minimum_lr": 2.549307318072117e-06}
# [04/25/2019 15:07:49 INFO 140169155405632] Saved checkpoint to "/tmp/tmp8URlXS/mx-mod-0000.params"
# [2019-04-25 15:07:49.049] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/test", "epoch": 0, "duration": 213390, "num_examples": 1}
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 59, "sum": 59.0, "min": 59}, "Number of Batches Since Last Reset": {"count": 1, "max": 59, "sum": 59.0, "min": 59}, "Number of Records Since Last Reset": {"count": 1, "max": 58102, "sum": 58102.0, "min": 58102}, "Total Batches Seen": {"count": 1, "max": 59, "sum": 59.0, "min": 59}, "Total Records Seen": {"count": 1, "max": 58102, "sum": 58102.0, "min": 58102}, "Max Records Seen Between Resets": {"count": 1, "max": 58102, "sum": 58102.0, "min": 58102}, "Reset Count": {"count": 1, "max": 1, "sum": 1.0, "min": 1}}, "EndTime": 1556204869.507084, "Dimensions": {"Host": "algo-1", "Meta": "test_data_iter", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1556204869.048628}
#
# [04/25/2019 15:07:49 INFO 140169155405632] #test_score (algo-1) : ('multiclass_cross_entropy_objective', 0.64798191516092696)
# [04/25/2019 15:07:49 INFO 140169155405632] #test_score (algo-1) : ('multiclass_accuracy', 0.72185122715224947)
# [04/25/2019 15:07:49 INFO 140169155405632] #test_score (algo-1) : ('multiclass_top_k_accuracy_3', 0.992289422050876)
# [04/25/2019 15:07:49 INFO 140169155405632] #test_score (algo-1) : ('dcg', 0.89195172008944967)
# [04/25/2019 15:07:49 INFO 140169155405632] #test_score (algo-1) : ('macro_recall', 0.47176784)
# [04/25/2019 15:07:49 INFO 140169155405632] #test_score (algo-1) : ('macro_precision', 0.57592952)
# [04/25/2019 15:07:49 INFO 140169155405632] #test_score (algo-1) : ('macro_f_1.000', 0.4873707)
# [04/25/2019 15:07:49 INFO 140169155405632] #quality_metric: host=algo-1, test multiclass_cross_entropy_objective <loss>=0.647981915161
# [04/25/2019 15:07:49 INFO 140169155405632] #quality_metric: host=algo-1, test multiclass_accuracy <score>=0.721851227152
# [04/25/2019 15:07:49 INFO 140169155405632] #quality_metric: host=algo-1, test multiclass_top_k_accuracy_3 <score>=0.992289422051
# [04/25/2019 15:07:49 INFO 140169155405632] #quality_metric: host=algo-1, test dcg <score>=0.891951720089
# [04/25/2019 15:07:49 INFO 140169155405632] #quality_metric: host=algo-1, test macro_recall <score>=0.47176784277
# [04/25/2019 15:07:49 INFO 140169155405632] #quality_metric: host=algo-1, test macro_precision <score>=0.575929522514
# [04/25/2019 15:07:49 INFO 140169155405632] #quality_metric: host=algo-1, test macro_f_1.000 <score>=0.487370699644
# [2019-04-25 15:07:49.516] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 10, "duration": 25664, "num_examples": 465}
# [2019-04-25 15:07:49.516] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "duration": 213665, "num_epochs": 11, "num_examples": 4197}
# [2019-04-25 15:07:49.516] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/validation", "epoch": 11, "duration": 928, "num_examples": 59}
# [2019-04-25 15:07:49.516] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/validation", "duration": 213858, "num_epochs": 12, "num_examples": 650}
# [2019-04-25 15:07:49.516] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/test", "epoch": 1, "duration": 466, "num_examples": 59}
# [2019-04-25 15:07:49.516] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/test", "duration": 213856, "num_epochs": 2, "num_examples": 60}
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 213964.3840789795, "sum": 213964.3840789795, "min": 213964.3840789795}, "finalize.time": {"count": 1, "max": 1903.2411575317383, "sum": 1903.2411575317383, "min": 1903.2411575317383}, "initialize.time": {"count": 1, "max": 388.5838985443115, "sum": 388.5838985443115, "min": 388.5838985443115}, "check_early_stopping.time": {"count": 10, "max": 1.27410888671875, "sum": 6.183624267578125, "min": 0.18095970153808594}, "setuptime": {"count": 1, "max": 19.208192825317383, "sum": 19.208192825317383, "min": 19.208192825317383}, "update.time": {"count": 9, "max": 23931.35905265808, "sum": 211075.97398757935, "min": 23229.891061782837}, "epochs": {"count": 1, "max": 15, "sum": 15.0, "min": 15}}, "EndTime": 1556204869.517038, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1556204655.643548}
# 2019-04-25 15:07:54 Uploading - Uploading generated training model
# 2019-04-25 15:07:54 Completed - Training job completed
# Billable seconds: 259

# %% [markdown]
# ## Multiclass classification metrics

# %% [markdown]
# Now that we have a trained model, we want to make predictions and evaluate model performance on our test set. For that we'll need to deploy a model hosting endpoint to accept inference requests using the estimator API:

# %%
# deploy a model hosting endpoint
multiclass_predictor = multiclass_estimator.deploy(initial_instance_count=1, instance_type='ml.m4.xlarge')
# Out:
# INFO:sagemaker:Creating model with name: linear-learner-2019-04-25-15-08-31-371
# INFO:sagemaker:Creating endpoint with name linear-learner-2019-04-25-15-01-16-749
# ----------------------------------------------------------------------------------------!

# %% [markdown]
# We'll add a convenience function for parsing predictions and evaluating model metrics. It will feed test features to the endpoint and receive predicted test labels. To evaluate the models we create, we'll capture predicted test labels and compare them to actuals using some common multiclass classification metrics. As mentioned earlier, we're extracting the `predicted_label` from each response payload. That's the class with the highest predicted probability. We'll get one class label per example. To get a vector of seven probabilities for each example (the predicted probability for each class) , we would extract the `score` from the response payload. Details of linear learner's response format are in the [documentation](https://docs.aws.amazon.com/sagemaker/latest/dg/LL-in-formats.html).

# %%
def evaluate_metrics(predictor, test_features, test_labels):
    """
    Evaluate a model on a test set using the given prediction endpoint. Display classification metrics.
    """
    # split the test dataset into 100 batches and evaluate using prediction endpoint
    prediction_batches = [predictor.predict(batch) for batch in np.array_split(test_features, 100)]

    # parse protobuf responses to extract predicted labels
    extract_label = lambda x: x.label['predicted_label'].float32_tensor.values
    test_preds = np.concatenate([np.array([extract_label(x) for x in batch]) for batch in prediction_batches])
    test_preds = test_preds.reshape((-1,))
    
    # calculate accuracy
    accuracy = (test_preds == test_labels).sum() / test_labels.shape[0]
    
    # calculate recall for each class
    recall_per_class, classes = [], []
    for target_label in np.unique(test_labels):
        recall_numerator = np.logical_and(test_preds == target_label, test_labels == target_label).sum()
        recall_denominator = (test_labels == target_label).sum()
        recall_per_class.append(recall_numerator / recall_denominator)
        classes.append(label_map[target_label])
    recall = pd.DataFrame({'recall': recall_per_class, 'class_label': classes})
    recall.sort_values('class_label', ascending=False, inplace=True)

    # calculate confusion matrix
    label_mapper = np.vectorize(lambda x: label_map[x])
    confusion_matrix = pd.crosstab(label_mapper(test_labels), label_mapper(test_preds), 
                                   rownames=['Actuals'], colnames=['Predictions'], normalize='index')

    # display results
    sns.heatmap(confusion_matrix, annot=True, fmt='.2f', cmap="YlGnBu").set_title('Confusion Matrix')  
    ax = recall.plot(kind='barh', x='class_label', y='recall', color='steelblue', title='Recall', legend=False)
    ax.set_ylabel('')
    print('Accuracy: {:.3f}'.format(accuracy))

# %%
# evaluate metrics of the model trained with default hyperparameters
evaluate_metrics(multiclass_predictor, test_features, test_labels)
# Out:
# Accuracy: 0.722

# %% [markdown]
# The first metric reported is accuracy. Accuracy for multiclass classification means the same thing as it does for binary classification: the percent of predicted labels which match ground-truth labels. Our model predicts the right type of forest cover over 72% of the time.

# %% [markdown]
# Next we see the confusion matrix and a plot of class recall for each label. Recall is a binary classification metric which is also useful in the multiclass setting. It measures the model's accuracy when the true label belongs to the first class, the second class, and so on. If we average the recall values across all classes, we get a metric called *macro recall*, which you can find reported in the algorithm logs. You'll also find *macro precision* and *macro f-score*, which are constructed the same way.

# %% [markdown]
# The recall achieved by our model varies widely among the classes. Recall is high for the most common labels, but is very poor for the rarer labels like Aspen or Cottonwood/Willow. Our predictions are right most of the time, but when the true cover type is a rare one like Aspen or Cottonwood/Willow, our model tends to predict wrong.

# %% [markdown]
# A confusion matrix is a tool for visualizing the performance of a multiclass model. It has entries for all possible combinations of correct and incorrect predictions, and shows how often each one was made by our model. It has been row-normalized: each row sums to one, so that entries along the diagonal correspond to recall. For example, the first row shows that when the true label is Aspen, the model predicts correctly only 1% of the time, and incorrectly predicts Lodgepole Pine 95% of the time. The second row shows that when the true forest cover type is Cottonwood/Willow, the model has 27% recall, and incorrectly predicts Ponderosa Pine 65% of the time. If our model had 100% accuracy, and therefore 100% recall in every class, then all of the predictions would fall along the diagonal of the confusion matrix.

# %% [markdown]
# It's normal that the model performs poorly on very rare classes. It doesn't have much data to learn about them, and it was optimized for global performance. By default, linear learner uses the softmax loss function, which optimizes the likelihood of a multinomial distribution. It's similar in principle to optimizing global accuracy.

# %% [markdown]
# But what if one of the rare class labels is especially important to our use case? For example, maybe we're predicting customer outcomes, and one of the potential outcomes is a dissatisfied customer. Hopefully that's a rare outcome, but it might be one that's especially important to predict and act on quickly. In that case, we might be able to sacrifice a bit of overall accuracy in exchange for much improved recall on rare classes. Let's see how.

# %% [markdown]
# ## Training with balanced class weights

# %% [markdown]
# Class weights alter the loss function optimized by the linear learner algorithm. They put more weight on rarer classes so that the importance of each class is equal. Without class weights, each example in the training set is treated equally. If 80% of those examples have labels from one overrepresented class, that class will get 80% of the attention during model training. With balanced class weights, each class has the same amount of influence during training.

# %% [markdown]
# With balanced class weights turned on, linear learner will count label frequencies in your training set. This is done efficiently using a sample of the training set. The weights will be the inverses of the frequencies. A label that's present in 1/3 of the sampled training examples will get a weight of 3, and a rare label that's present in only 0.001% of the examples will get a weight of 100,000. A label that's not present at all in the sampled training examples will get a weight of 1,000,000 by default. To turn on class weights, use the `balance_multiclass_weights` hyperparameter:

# %%
# instantiate the LinearLearner estimator object
balanced_multiclass_estimator = sagemaker.LinearLearner(role=sagemaker.get_execution_role(),
                                                        train_instance_count=1,
                                                        train_instance_type='ml.m4.xlarge',
                                                        predictor_type='multiclass_classifier',
                                                        num_classes=7,
                                                        balance_multiclass_weights=True)
# Out:
# INFO:sagemaker:Created S3 bucket: sagemaker-us-east-1-023375022819

# %%
# start a training job
balanced_multiclass_estimator.fit([train_records, val_records, test_records])
# Out:
# INFO:sagemaker:Creating training-job with name: linear-learner-2019-04-25-15-16-07-190
# 2019-04-25 15:16:07 Starting - Starting the training job...
# 2019-04-25 15:16:09 Starting - Launching requested ML instances......
# 2019-04-25 15:17:16 Starting - Preparing the instances for training...
# 2019-04-25 15:18:02 Downloading - Downloading input data...
# 2019-04-25 15:18:11 Training - Downloading the training image...
# 2019-04-25 15:18:55 Training - Training image download completed. Training in progress.
# Docker entrypoint called with argument(s): train
# [04/25/2019 15:18:57 INFO 139981302499136] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/default-input.json: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [04/25/2019 15:18:57 INFO 139981302499136] Reading provided configuration from /opt/ml/input/config/hyperparameters.json: {u'feature_dim': u'54', u'mini_batch_size': u'1000', u'num_classes': u'7', u'balance_multiclass_weights': u'True', u'predictor_type': u'multiclass_classifier'}
# [04/25/2019 15:18:57 INFO 139981302499136] Final configuration: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'54', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'7', u'predictor_type': u'multiclass_classifier', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'True', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [04/25/2019 15:18:57 WARNING 139981302499136] Loggers have already been setup.
# Process 1 is a worker.
# [04/25/2019 15:18:57 INFO 139981302499136] Using default worker.
# [2019-04-25 15:18:57.708] [tensorio] [info] batch={"data_pipeline": "/opt/ml/input/data/train", "num_examples": 1000, "features": [{"name": "label_values", "shape": [1], "storage_type": "dense"}, {"name": "values", "shape": [54], "storage_type": "dense"}]}
# [2019-04-25 15:18:57.712] [tensorio] [warning] TensorIO is already initialized; ignoring the initialization routine.
# [2019-04-25 15:18:57.713] [tensorio] [info] batch={"data_pipeline": "/opt/ml/input/data/validation", "num_examples": 1000, "features": [{"name": "label_values", "shape": [1], "storage_type": "dense"}, {"name": "values", "shape": [54], "storage_type": "dense"}]}
# [2019-04-25 15:18:57.718] [tensorio] [warning] TensorIO is already initialized; ignoring the initialization routine.
# [2019-04-25 15:18:57.724] [tensorio] [info] batch={"data_pipeline": "/opt/ml/input/data/test", "num_examples": 1000, "features": [{"name": "label_values", "shape": [1], "storage_type": "dense"}, {"name": "values", "shape": [54], "storage_type": "dense"}]}
# [2019-04-25 15:18:57.769] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 0, "duration": 61, "num_examples": 1}
# [04/25/2019 15:18:57 INFO 139981302499136] Create Store: local
# [2019-04-25 15:18:57.960] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 1, "duration": 188, "num_examples": 11}
# [04/25/2019 15:18:57 INFO 139981302499136] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7f4f93a0ce10>
# [04/25/2019 15:18:57 INFO 139981302499136] Scaling model computed with parameters:
#  {'stdev_weight':
# [  2.78764069e+02   1.12227264e+02   7.43960190e+00   2.11538040e+02
#    5.84749680e+01   1.57234204e+03   2.67115593e+01   1.95506935e+01
#    3.82310791e+01   1.31177246e+03   4.97904658e-01   2.21659780e-01
#    4.95366931e-01   2.40825027e-01   7.72269443e-02   1.12882435e-01
"Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1556205564.914877}
#
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 2.105209366343452, "sum": 2.105209366343452, "min": 2.105209366343452}}, "EndTime": 1556205564.914954, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1556205564.914938}
#
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 2.697891835712861, "sum": 2.697891835712861, "min": 2.697891835712861}}, "EndTime": 1556205564.915014, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1556205564.914997}
#
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 2.120209140737866, "sum": 2.120209140737866, "min": 2.120209140737866}}, "EndTime": 1556205564.915071, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1556205564.915055}
#
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 2.3582999661663053, "sum": 2.3582999661663053, "min": 2.3582999661663053}}, "EndTime": 1556205564.915139, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1556205564.915123}
#
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 2.0944253402791113, "sum": 2.0944253402791113, "min": 2.0944253402791113}}, "EndTime": 1556205564.915201, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1556205564.915184}
#
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 2.0510448325088833, "sum": 2.0510448325088833, "min": 2.0510448325088833}}, "EndTime": 1556205564.915262, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1556205564.915245}
#
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 2.7974176583311685, "sum": 2.7974176583311685, "min": 2.7974176583311685}}, "EndTime": 1556205564.915322, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1556205564.915305}
#
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 2.5790022318565207, "sum": 2.5790022318565207, "min": 2.5790022318565207}}, "EndTime": 1556205564.915381, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1556205564.915365}
#
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 2.1378621417695083, "sum": 2.1378621417695083, "min": 2.1378621417695083}}, "EndTime": 1556205564.915439, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1556205564.915423}
#
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 2.419955721878291, "sum": 2.419955721878291, "min": 2.419955721878291}}, "EndTime": 1556205564.915496, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1556205564.915481}
#
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 2.516179531880889, "sum": 2.516179531880889, "min": 2.516179531880889}}, "EndTime": 1556205564.915561, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1556205564.915545}
#
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 2.806247207138149, "sum": 2.806247207138149, "min": 2.806247207138149}}, "EndTime": 1556205564.915621, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1556205564.915605}
#
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 2.2335248637147287, "sum": 2.2335248637147287, "min": 2.2335248637147287}}, "EndTime": 1556205564.915682, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1556205564.915665}
#
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 3.3978303109706385, "sum": 3.3978303109706385, "min": 3.3978303109706385}}, "EndTime": 1556205564.915726, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1556205564.915716}
#
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 2.246811996152427, "sum": 2.246811996152427, "min": 2.246811996152427}}, "EndTime": 1556205564.915762, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1556205564.915748}
#
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 2.315093124851081, "sum": 2.315093124851081, "min": 2.315093124851081}}, "EndTime": 1556205564.915826, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1556205564.915809}
#
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 2.176941494693777, "sum": 2.176941494693777, "min": 2.176941494693777}}, "EndTime": 1556205564.915942, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1556205564.915922}
#
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 2.244146821642535, "sum": 2.244146821642535, "min": 2.244146821642535}}, "EndTime": 1556205564.916002, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1556205564.915986}
#
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 2.0702445060627688, "sum": 2.0702445060627688, "min": 2.0702445060627688}}, "EndTime": 1556205564.91606, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1556205564.916044}
#
# [04/25/2019 15:19:24 INFO 139981302499136] #quality_metric: host=algo-1, epoch=0, validation weighted_softmax_loss_objective <loss>=2.1399028276
# [04/25/2019 15:19:24 INFO 139981302499136] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=weighted_softmax_loss_objective, value=2.05104483251
# [04/25/2019 15:19:24 INFO 139981302499136] Epoch 0: Loss improved. Updating best model
# [04/25/2019 15:19:24 INFO 139981302499136] #progress_metric: host=algo-1, completed 6 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 465, "sum": 465.0, "min": 465}, "Number of Batches Since Last Reset": {"count": 1, "max": 465, "sum": 465.0, "min": 465}, "Number of Records Since Last Reset": {"count": 1, "max": 464808, "sum": 464808.0, "min": 464808}, "Total Batches Seen": {"count": 1, "max": 477, "sum": 477.0, "min": 477}, "Total Records Seen": {"count": 1, "max": 476808, "sum": 476808.0, "min": 476808}, "Max Records Seen Between Resets": {"count": 1, "max": 464808, "sum": 464808.0, "min": 464808}, "Reset Count": {"count": 1, "max": 3, "sum": 3.0, "min": 3}}, "EndTime": 1556205564.917771, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1556205538.185107}
#
# [04/25/2019 15:19:24 INFO 139981302499136] #throughput_metric: host=algo-1, train throughput=17387.1875431 records/second
# [2019-04-25 15:19:24.918] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch":

#
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 2.087301270325429, "sum": 2.087301270325429, "min": 2.087301270325429}}, "EndTime": 1556205592.026445, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1556205592.026429}
#
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 2.1449465986451326, "sum": 2.1449465986451326, "min": 2.1449465986451326}}, "EndTime": 1556205592.026504, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1556205592.026489}
#
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 2.036585067082218, "sum": 2.036585067082218, "min": 2.036585067082218}}, "EndTime": 1556205592.02656, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1556205592.026545}
#
# [04/25/2019 15:19:52 INFO 139981302499136] #quality_metric: host=algo-1, epoch=1, validation weighted_softmax_loss_objective <loss>=2.10354132787
# [04/25/2019 15:19:52 INFO 139981302499136] #early_stopping_criteria_metric: host=algo-1, epoch=1, criteria=weighted_softmax_loss_objective, value=1.98945448361
# [04/25/2019 15:19:52 INFO 139981302499136] Epoch 1: Loss improved. Updating best model
# [04/25/2019 15:19:52 INFO 139981302499136] #progress_metric: host=algo-1, completed 13 % of epochs
# ...
#
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 1.9700524082007551, "sum": 1.9700524082007551, "min": 1.9700524082007551}}, "EndTime": 1556205911.523923, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1556205911.523906}
#
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 2.0891518535631413, "sum": 2.0891518535631413, "min": 2.0891518535631413}}, "EndTime": 1556205911.523982, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1556205911.523965}
#
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 1.9537540678128456, "sum": 1.9537540678128456, "min": 1.9537540678128456}}, "EndTime": 1556205911.524039, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1556205911.524023}
#
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 1.9895020938921286, "sum": 1.9895020938921286, "min": 1.9895020938921286}}, "EndTime": 1556205911.524095, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1556205911.52408}
#
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 1.9469349685301007, "sum": 1.9469349685301007, "min": 1.9469349685301007}}, "EndTime": 1556205911.524151, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1556205911.524136}
#
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 2.2140533530780453, "sum": 2.2140533530780453, "min": 2.2140533530780453}}, "EndTime": 1556205911.524206, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1556205911.524191}
#
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 2.0111620412184976, "sum": 2.0111620412184976, "min": 2.0111620412184976}}, "EndTime": 1556205911.524263, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1556205911.524247}
#
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 1.9685277688856373, "sum": 1.9685277688856373, "min": 1.9685277688856373}}, "EndTime": 1556205911.524319, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1556205911.524304}
#
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 2.4020191016077135, "sum": 2.4020191016077135, "min": 2.4020191016077135}}, "EndTime": 1556205911.524374, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1556205911.524359}
#
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 2.4176834793735567, "sum": 2.4176834793735567, "min": 2.4176834793735567}}, "EndTime": 1556205911.52443, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1556205911.524415}
#
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 1.9393401399450485, "sum": 1.9393401399450485, "min": 1.9393401399450485}}, "EndTime": 1556205911.524485, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1556205911.52447}
#
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 2.386895323716409, "sum": 2.386895323716409, "min": 2.386895323716409}}, "EndTime": 1556205911.524539, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1556205911.524525}
#
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 1.917235976732429, "sum": 1.917235976732429, "min": 1.917235976732429}}, "EndTime": 1556205911.524592, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1556205911.524578}
#
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 2.6077398185699123, "sum": 2.6077398185699123, "min": 2.6077398185699123}}, "EndTime": 1556205911.524646, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1556205911.524631}
#
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 2.0637199265421655, "sum": 2.0637199265421655, "min": 2.0637199265421655}}, "EndTime": 1556205911.524703, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1556205911.524687}
#
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 3.369377060725712, "sum": 3.369377060725712, "min": 3.369377060725712}}, "EndTime": 1556205911.524758, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1556205911.524743}
#
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 2.1523519394428554, "sum": 2.1523519394428554, "min": 2.1523519394428554}}, "EndTime": 1556205911.524812, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1556205911.524797}
#
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 2.3056497701718204, "sum": 2.3056497701718204, "min": 2.3056497701718204}}, "EndTime": 1556205911.524866, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1556205911.524852}
#
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 1.9239835235059422, "sum": 1.9239835235059422, "min": 1.9239835235059422}}, "EndTime": 1556205911.524921, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1556205911.524906}
#
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 1.991514360520399, "sum": 1.991514360520399, "min": 1.991514360520399}}, "EndTime": 1556205911.524975, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1556205911.524961}
#
# #metrics {"Metrics": {"validation_weighted_softmax_loss_objective": {"count": 1, "max": 2.0139078726668123, "sum": 2.0139078726668123, "min": 2.0139078726668123}}, "EndTime": 1556205911.525029, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1556205911.525014}
#
# [04/25/2019 15:25:11 INFO 139981302499136] #quality_metric: host=algo-1, epoch=13, validation weighted_softmax_loss_objective <loss>=2.08770123412
# [04/25/2019 15:25:11 INFO 139981302499136] #early_stopping_criteria_metric: host=algo-1, epoch=13, criteria=weighted_softmax_loss_objective, value=1.91723597673
# [04/25/2019 15:25:11 INFO 139981302499136] Early stop condition met. Stopping training.
# [04/25/2019 15:25:11 INFO 139981302499136] #progress_metric: host=algo-1, completed 100 % epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 465, "sum": 465.0, "min": 465}, "Number of Batches Since Last Reset": {"count": 1, "max": 465, "sum": 465.0, "min": 465}, "Number of Records Since Last Reset": {"count": 1, "max": 464808, "sum": 464808.0, "min": 464808}, "Total Batches Seen": {"count": 1, "max": 6522, "sum": 6522.0, "min": 6522}, "Total Records Seen": {"count": 1, "max": 6519312, "sum": 6519312.0, "min": 6519312}, "Max Records Seen Between Resets": {"count": 1, "max": 464808, "sum": 464808.0, "min": 464808}, "Reset Count": {"count": 1, "max": 16, "sum": 16.0, "min": 16}}, "EndTime": 1556205911.52637, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1556205884.735042}
#
# [04/25/2019 15:25:11 INFO 139981302499136] #throughput_metric: host=algo-1, train throughput=17349.1047636 records/second
# [04/25/2019 15:25:11 WARNING 139981302499136] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [04/25/2019 15:25:11 WARNING 139981302499136] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2019-04-25 15:25:11.558] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/validation", "epoch": 14, "duration": 1686, "num_examples": 59}
# [04/25/2019 15:25:13 INFO 139981302499136] #early_stopping_criteria_metric: host=algo-1, epoch=13, criteria=weighted_softmax_loss_objective, value=1.91723597673
# [2019-04-25 15:25:13.228] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/validation", "epoch": 15, "duration": 1669, "num_examples": 59}
# [04/25/2019 15:25:13 INFO 139981302499136] #validation_score (algo-1) : ('weighted_softmax_loss_objective', 1.9201039987756032)
# [04/25/2019 15:25:13 INFO 139981302499136] #validation_score (algo-1) : ('multiclass_accuracy', 0.5936902979294677)
# [04/25/2019 15:25:13 INFO 139981302499136] #validation_score (algo-1) : ('multiclass_top_k_accuracy_3', 0.97549095540524255)
# [04/25/2019 15:25:13 INFO 139981302499136] #validation_score (algo-1) : ('dcg', 0.83551292861300563)
# [04/25/2019 15:25:13 INFO 139981302499136] #validation_score (algo-1) : ('macro_recall', 0.69442648)
# [04/25/2019 15:25:13 INFO 139981302499136] #validation_score (algo-1) : ('macro_precision', 0.46126586)
# [04/25/2019 15:25:13 INFO 139981302499136] #validation_score (algo-1) : ('macro_f_1.000', 0.49148506)
# [04/25/2019 15:25:13 INFO 139981302499136] #quality_metric: host=algo-1, validation weighted_softmax_loss_objective <loss>=1.92010399878
# [04/25/2019 15:25:13 INFO 139981302499136] #quality_metric: host=algo-1, validation multiclass_accuracy <score>=0.593690297929
# [04/25/2019 15:25:13 INFO 139981302499136] #quality_metric: host=algo-1, validation multiclass_top_k_accuracy_3 <score>=0.975490955405
# [04/25/2019 15:25:13 INFO 139981302499136] #quality_metric: host=algo-1, validation dcg <score>=0.835512928613
# [04/25/2019 15:25:13 INFO 139981302499136] #quality_metric: host=algo-1, validation macro_recall <score>=0.694426476955
# [04/25/2019 15:25:13 INFO 139981302499136] #quality_metric: host=algo-1, validation macro_precision <score>=0.461265861988
# [04/25/2019 15:25:13 INFO 139981302499136] #quality_metric: host=algo-1, validation macro_f_1.000 <score>=0.491485059261
# [04/25/2019 15:25:13 INFO 139981302499136] Best model found for hyperparameters: {"lr_scheduler_step": 23, "wd": 0.0017784998070751394, "optimizer": "rmsprop", "lr_scheduler_factor": 0.9799145575886673, "l1": 0.001434532164232352, "learning_rate": 0.07976296686711583, "lr_scheduler_minimum_lr": 0.00013890692540260633}
# [04/25/2019 15:25:13 INFO 139981302499136] Saved checkpoint to "/tmp/tmppJUvtM/mx-mod-0000.params"
# [2019-04-25 15:25:13.706] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/test", "epoch": 0, "duration": 375988, "num_examples": 1}
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 59, "sum": 59.0, "min": 59}, "Number of Batches Since Last Reset": {"count": 1, "max": 59, "sum": 59.0, "min": 59}, "Number of Records Since Last Reset": {"count": 1, "max": 58102, "sum": 58102.0, "min": 58102}, "Total Batches Seen": {"count": 1, "max": 59, "sum": 59.0, "min": 59}, "Total Records Seen": {"count": 1, "max": 58102, "sum": 58102.0, "min": 58102}, "Max Records Seen Between Resets": {"count": 1, "max": 58102, "sum": 58102.0, "min": 58102}, "Reset Count": {"count": 1, "max": 1, "sum": 1.0, "min": 1}}, "EndTime": 1556205914.196515, "Dimensions": {"Host": "algo-1", "Meta": "test_data_iter", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1556205913.706006}
#
# [04/25/2019 15:25:14 INFO 139981302499136] #test_score (algo-1) : ('weighted_softmax_loss_objective', 1.9264668831049376)
# [04/25/2019 15:25:14 INFO 139981302499136] #test_score (algo-1) : ('multiclass_accuracy', 0.59175243537227629)
# [04/25/2019 15:25:14 INFO 139981302499136] #test_score (algo-1) : ('multiclass_top_k_accuracy_3', 0.97494062166534712)
# [04/25/2019 15:25:14 INFO 139981302499136] #test_score (algo-1) : ('dcg', 0.83459102229724702)
# [04/25/2019 15:25:14 INFO 139981302499136] #test_score (algo-1) : ('macro_recall', 0.69426429)
# [04/25/2019 15:25:14 INFO 139981302499136] #test_score (algo-1) : ('macro_precision', 0.46260786)
# [04/25/2019 15:25:14 INFO 139981302499136] #test_score (algo-1) : ('macro_f_1.000', 0.49447456)
# [04/25/2019 15:25:14 INFO 139981302499136] #quality_metric: host=algo-1, test weighted_softmax_loss_objective <loss>=1.9264668831
# [04/25/2019 15:25:14 INFO 139981302499136] #quality_metric: host=algo-1, test multiclass_accuracy <score>=0.591752435372
# [04/25/2019 15:25:14 INFO 139981302499136] #quality_metric: host=algo-1, test multiclass_top_k_accuracy_3 <score>=0.974940621665
# [04/25/2019 15:25:14 INFO 139981302499136] #quality_metric: host=algo-1, test dcg <score>=0.834591022297
# [04/25/2019 15:25:14 INFO 139981302499136] #quality_metric: host=algo-1, test macro_recall <score>=0.694264292717
# [04/25/2019 15:25:14 INFO 139981302499136] #quality_metric: host=algo-1, test macro_precision <score>=0.462607860565
# [04/25/2019 15:25:14 INFO 139981302499136] #quality_metric: host=algo-1, test macro_f_1.000 <score>=0.494474560022
# [2019-04-25 15:25:14.207] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 15, "duration": 29472, "num_examples": 465}
# [2019-04-25 15:25:14.207] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "duration": 376264, "num_epochs": 16, "num_examples": 6522}
# [2019-04-25 15:25:14.212] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/validation", "epoch": 16, "duration": 983, "num_examples": 59}
# [2019-04-25 15:25:14.212] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/validation", "duration": 376489, "num_epochs": 17, "num_examples": 945}
# [2019-04-25 15:25:14.212] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/test", "epoch": 1, "duration": 505, "num_examples": 59}
# [2019-04-25 15:25:14.212] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/test", "duration": 376493, "num_epochs": 2, "num_examples": 60}
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 376599.6880531311, "sum": 376599.6880531311, "min": 376599.6880531311}, "finalize.time": {"count": 1, "max": 2174.3521690368652, "sum": 2174.3521690368652, "min": 2174.3521690368652}, "initialize.time": {"count": 1, "max": 450.6418704986572, "sum": 450.6418704986572, "min": 450.6418704986572}, "check_early_stopping.time": {"count": 15, "max": 1.1780261993408203, "sum": 9.266376495361328, "min": 0.20194053649902344}, "setuptime": {"count": 1, "max": 16.10398292541504, "sum": 16.10398292541504, "min": 16.10398292541504}, "update.time": {"count": 14, "max": 27109.96103286743, "sum": 373334.56897735596, "min": 26422.832012176514}, "epochs": {"count": 1, "max": 15, "sum": 15.0, "min": 15}}, "EndTime": 1556205914.213258, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1556205537.706802}
# 2019-04-25 15:25:23 Uploading - Uploading generated training model
# 2019-04-25 15:25:23 Completed - Training job completed
# Billable seconds: 441

# %%
# deploy a model hosting endpoint
balanced_multiclass_predictor = balanced_multiclass_estimator.deploy(initial_instance_count=1, 
                                                                     instance_type='ml.m4.xlarge')
# Out:
# INFO:sagemaker:Creating model with name: linear-learner-2019-04-25-15-25-53-765
# INFO:sagemaker:Creating endpoint with name linear-learner-2019-04-25-15-16-07-190
# -----------------------------------------------------------------------------!

# %%
# evaluate metrics of the model trained with balanced class weights
evaluate_metrics(balanced_multiclass_predictor, test_features, test_labels)
# Out:
# Accuracy: 0.592

# %% [markdown]
# The difference made by class weights is immediately clear from the confusion matrix. The predictions now line up nicely along the diagonal of the matrix, meaning predicted labels match actual labels. Recall for the rare Aspen class was only 1%, but now recall for every class is above 50%. That's a huge improvement in our ability to predict rare labels correctly.

# %% [markdown]
# But remember that the confusion matrix has each row normalized to sum to 1. Visually, we've given each class equal weight in our diagnostic tool. That emphasizes the gains we've made in rare classes, but it de-emphasizes the price we'll pay in terms of predicting more common classes. Recall for the most common class, Lodgepole Pine, has gone from 81% to 52%. For that reason, overall accuracy also decreased from 72% to 59%. To decide whether to use balanced class weights for your application, consider the business impact of making errors in common cases and how it compares to the impact of making errors in rare cases.

# %% [markdown]
# #### Deleting the hosting endpoints

# %% [markdown]
# Finally, we'll delete the hosting endpoints. The machines used for training spin down automatically, but the hosting endpoints remain active until you shut them down.

# %%
# delete endpoints
multiclass_predictor.delete_endpoint()
balanced_multiclass_predictor.delete_endpoint()
# Out:
# INFO:sagemaker:Deleting endpoint configuration with name: linear-learner-2019-04-25-15-01-16-749
# INFO:sagemaker:Deleting endpoint with name: linear-learner-2019-04-25-15-01-16-749
# INFO:sagemaker:Deleting endpoint configuration with name: linear-learner-2019-04-25-15-16-07-190
# INFO:sagemaker:Deleting endpoint with name: linear-learner-2019-04-25-15-16-07-190

# %% [markdown]
# ## Conclusion

# %% [markdown]
# In this example notebook, we introduced the new multiclass classification feature of the Amazon SageMaker linear learner algorithm. We showed how to fit a multiclass model using the convenient high-level estimator API, and how to evaluate and interpret model metrics. We also showed how to achieve higher recall for rare classes using linear learner's automatic class weights calculation. Try Amazon SageMaker and linear learner on your classification problems today!
